# %%
import os
import time
import numpy as np
import pydicom
import glob
import shutil
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt
import sys
import logging
import cv2
import pandas as pd
import subprocess

# %%
#load excel
path_excel = '/data/4TB1/pipeline/chuan/excel/'

excel_name = 'ClinicalTest.xlsx'
#excel_name = 'AI_Normal.xlsx'

#先讀取excel，取得patientid跟accession_number當成資料夾檔名條件
dtypes1 = {'ID': str, 'PatientID': str, 'StudyDate': str, 'AccessionNumber': str, 'SubjectLabel': str, 'ExperimentLabel': str, 
          'SeriesInstanceUID': str, 'url': str}

df = pd.read_excel(os.path.join(path_excel, excel_name), dtype=dtypes1).fillna('')
IDs = list(df['ID'])

# %%
for idx, ID in enumerate(IDs):
    print([idx], ID, ' Start...')
    Inputs = os.path.join('/data/4TB1/pipeline/chuan/example_input', ID, 'MRA_BRAIN.nii.gz')
    DicomDir = os.path.join('/data/4TB1/pipeline/chuan/example_inputDicom', ID, 'MRA_BRAIN')
    Output_folder = '/data/4TB1/pipeline/chuan/example_output/'
    cmd = [
           "python", "pipeline_aneurysm_torch.py",
           "--ID", ID,
           "--Inputs", Inputs,
           "--DicomDir", DicomDir,
           "--Output_folder", Output_folder,
          ]

    subprocess.run(cmd)
# Out:
# [0] 00719692_20250522_MR_21405210094  Start...
# 2025-06-16 14:19:01.215273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-16 14:19:01.215297: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-16 14:19:01.215303: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 14:19:01.219325: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-16 14:19:05.785687: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:19:05.788731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:19:05.792210: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:19:05.795042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:19:05.797351: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:19:05.800110: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# >>> predict_vessel_16labels .................>>> (512, 512, 148)
# >>> Resampling inputs...
# >>> Computing importance map...
# >>> Running sliding window inference...
# .................batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ...............batch_tensor (319, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# >>> Postprocessing predictions...
# >>> Done. (512, 512, 148)
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/brain_mask.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Vessel.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Vessel_16.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Pred.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Prob.nii.gz
# 00719692_20250522_MR_21405210094  Start...
# Running stage 1: Aneurysm inference!!!
# end!!!
# [1] 00921585_20250530_MR_21405290061  Start...
# 2025-06-16 14:25:58.750628: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-16 14:25:58.750653: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-16 14:25:58.750659: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 14:25:58.754752: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-16 14:26:03.420134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:26:03.423504: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:26:03.454361: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:26:03.463675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:26:03.466760: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:26:03.469601: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# >>> predict_vessel_16labels .................>>> (512, 512, 136)
# >>> Resampling inputs...
# >>> Computing importance map...
# >>> Running sliding window inference...
# ...............batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ...batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ...........batch_tensor (46, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# >>> Postprocessing predictions...
# >>> Done. (512, 512, 136)
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/brain_mask.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Vessel.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Vessel_16.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Pred.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Prob.nii.gz
# 00921585_20250530_MR_21405290061  Start...
# Running stage 1: Aneurysm inference!!!
# end!!!
# [2] 00926164_20250603_MR_21405290024  Start...
# 2025-06-16 14:32:34.216118: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-16 14:32:34.216143: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-16 14:32:34.216149: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-16 14:32:34.220261: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-16 14:32:38.806099: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:32:38.814668: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:32:38.818016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:32:38.820870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:32:38.824226: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-16 14:32:38.827001: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# >>> predict_vessel_16labels .................>>> (512, 512, 144)
# >>> Resampling inputs...
# >>> Computing importance map...
# >>> Running sliding window inference...
# .................batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ..batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# .batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# ...batch_tensor (600, 32, 32, 16, 1) importance_map: (1, 32, 32, 16, 1)
# 